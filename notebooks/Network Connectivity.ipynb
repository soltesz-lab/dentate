# %%
import os, sys
from os.path import expanduser

user_home = expanduser("~")
neuron_home = '%s/bin/nrnpython2/lib/python' % user_home
model_home = '%s/src/model' % user_home
dentate_home = '%s/dentate' % model_home
sys.path.append(neuron_home) 
sys.path.append(model_home) 
sys.path.append('%s/btmorph' % dentate_home) 

import dentate
from dentate import utils, plot
from dentate.env import Env

# %%
verbose = True
config_prefix='%s/config' % dentate_home
config='Full_Scale_Pas.yaml'
template_paths='%s/templates' % dentate_home


utils.config_logging(verbose)
logger = utils.get_script_logger('vertex metrics')

env = Env(config_file=config, config_prefix=config_prefix, template_paths=template_paths)
# Out:
# INFO:dentate:dataset_prefix = None
# INFO:dentate:projection_dict = defaultdict(<type 'list'>, {})
# INFO:dentate.neuron_utils:Loaded StimCell from /home/igr/src/model/dentate/templates/StimCell.hoc
# INFO:dentate.neuron_utils:Loaded VecStimCell from /home/igr/src/model/dentate/templates/VecStimCell.hoc

# %%
dataset_prefix='/media/igr/d865f900-7fcd-45c7-a7a7-bd2a7391bc40/Data/DG/Full_Scale_Control'
GC_connections_path='%s/DG_GC_connections_20181225_compressed.h5' % dataset_prefix
IN_connections_path='%s/DG_IN_connections_20190325_compressed.h5' % dataset_prefix
Ext_IN_connections_path='%s/DG_Ext_IN_connections_20190122_compressed.h5' % dataset_prefix
MC_connections_path='%s/DG_MC_connections_20190430_compressed.h5' % dataset_prefix

coords_path='%s/datasets/DG_coords_20190122.h5' % dentate_home
vertex_metrics_namespace='Vertex Metrics'
distances_namespace='Arc Distances'
metric='Indegree'
normed=False
font_size=24

# %%
destination='GC'
sources=['MPP']

plot.plot_vertex_metrics (env, GC_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=50,
                          fontSize=font_size, graph_type='histogram1d', saveFig=True, figFormat='svg')
plot.plot_vertex_metrics (env, GC_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=150,
                          fontSize=font_size, graph_type='histogram2d', saveFig=True, figFormat='svg')
# Out:
# INFO:dentate.plot:projection: MPP -> GC: max: 6121 min: 431 mean: 2096 stdev: 520
# /home/igr/.local/lib/python2.7/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# INFO:dentate.plot:projection: MPP -> GC: max: 6121 min: 431 mean: 2096 stdev: 520

# %%
destination='GC'
sources=['MC']

plot.plot_vertex_metrics (env, GC_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=50,
                          fontSize=font_size, graph_type='histogram1d', saveFig=True, figFormat='svg')
plot.plot_vertex_metrics (env, GC_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=150,
                          fontSize=font_size, graph_type='histogram2d', saveFig=True, figFormat='svg')
# Out:
# INFO:dentate.plot:projection: MC -> GC: max: 4314 min: 145 mean: 1356 stdev: 412
# INFO:dentate.plot:projection: MC -> GC: max: 4314 min: 145 mean: 1356 stdev: 412

# %%
destination='GC'
sources=['BC']

plot.plot_vertex_metrics (env, GC_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=50,
                          fontSize=font_size, graph_type='histogram1d', saveFig=True, figFormat='svg')
plot.plot_vertex_metrics (env, GC_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=150,
                          fontSize=font_size, graph_type='histogram2d', saveFig=True, figFormat='svg')
# Out:
# INFO:dentate.plot:projection: BC -> GC: max: 1209 min: 202 mean: 510 stdev: 99
# INFO:dentate.plot:projection: BC -> GC: max: 1209 min: 202 mean: 510 stdev: 99

# %%
destination='GC'
sources=['BC']

plot.plot_vertex_metrics (env, GC_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=50,
                          fontSize=font_size, graph_type='histogram1d', saveFig=True, figFormat='svg')
plot.plot_vertex_metrics (env, GC_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=150,
                          fontSize=font_size, graph_type='histogram2d', saveFig=True, figFormat='svg')
# Out:
# INFO:dentate.plot:projection: BC -> GC: max: 1209 min: 202 mean: 510 stdev: 99
# INFO:dentate.plot:projection: BC -> GC: max: 1209 min: 202 mean: 510 stdev: 99

# %%
destination='HC'
sources=['MC']

plot.plot_vertex_metrics (env, IN_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=50,
                          fontSize=font_size, graph_type='histogram1d', saveFig=True, figFormat='svg')
plot.plot_vertex_metrics (env, IN_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=150,
                          fontSize=font_size, graph_type='histogram2d', saveFig=True, figFormat='svg')
# Out:
# INFO:dentate.plot:projection: MC -> HC: max: 1044 min: 814 mean: 932 stdev: 30
# INFO:dentate.plot:projection: MC -> HC: max: 1044 min: 814 mean: 932 stdev: 30

# %%
destination='MC'
sources=['MC']



plot.plot_vertex_metrics (env, MC_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=50,
                          fontSize=font_size, graph_type='histogram1d', saveFig=True)
plot.plot_vertex_metrics (env, MC_connections_path, coords_path, vertex_metrics_namespace, distances_namespace,
                          destination, sources, metric=metric, normed=normed, bin_size=150,
                          fontSize=font_size, graph_type='histogram2d', saveFig=True)
# Out:
# INFO:dentate.plot:projection: MC -> MC: max: 1329 min: 1053 mean: 1189 stdev: 35 (30000 units)
# /home/igr/.local/lib/python2.7/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# INFO:dentate.plot:projection: MC -> MC: max: 1329 min: 1053 mean: 1189 stdev: 35 (30000 units)

# %%
destination='BC'
source='MC'
target_gid = 1020650

plot.plot_single_vertex_dist (env, IN_connections_path, coords_path, distances_namespace, 
                              target_gid, destination, source, direction='out',
                              extent_type='global', bin_size=250, fontSize=font_size, saveFig=True, figFormat='svg')

# %%
destination='GC'
source='MC'
target_gid = 1010650

plot.plot_single_vertex_dist (env, GC_connections_path, coords_path, distances_namespace, 
                              target_gid, destination, source, direction='out',
                              extent_type='global', bin_size=250, fontSize=font_size, saveFig=True, figFormat='svg')

# %%
destination='GC'
source='MPP'
target_gid = 1056650+18748

plot.plot_single_vertex_dist (env, IN_connections_path, coords_path, distances_namespace, 
                              target_gid, destination, source, direction='out',
                              extent_type='global', bin_size=250, fontSize=font_size, saveFig=True, figFormat='svg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-43e3e5fcb886> in <module>()
#       5 plot.plot_single_vertex_dist (env, IN_connections_path, coords_path, distances_namespace,
#       6                               target_gid, destination, source, direction='out',
# ----> 7                               extent_type='global', bin_size=250, fontSize=font_size, saveFig=True, figFormat='svg')
#
# /home/igr/src/model/dentate/plot.py in plot_single_vertex_dist(env, connectivity_path, coords_path, distances_namespace, target_gid, destination, source, extent_type, direction, bin_size, **kwargs)
#     577                         update_bins(dist_v_bins, bin_size, dist_v)
#     578     else:
# --> 579         raise RuntimeError('Unknown direction type %s' % str(direction))
#     580
#     581     add_bins_op = MPI.Op.Create(add_bins, commute=True)
#
# ...

# %%
destination='GC'
source='MPP'
destination_gid = 672650

plot.plot_single_vertex_dist (env, GC_connections_path, coords_path, distances_namespace, 
                              destination_gid, destination, source, 
                              extent_type='global', bin_size=150, fontSize=font_size, saveFig=True, figFormat='svg')

# %%
destination='GC'
source='MC'
destination_gid = 672650

plot.plot_single_vertex_dist (env, GC_connections_path, coords_path, distances_namespace, 
                              destination_gid, destination, source, 
                              extent_type='global', bin_size=150, fontSize=font_size, saveFig=True, figFormat='svg')

# %%
destination='MC'
source='MC'
destination_gid = 1020650

plot.plot_single_vertex_dist (env, IN_connections_path, coords_path, distances_namespace, 
                              destination_gid, destination, source, 
                              extent_type='global', bin_size=150, fontSize=font_size, saveFig=True, figFormat='svg')

# %%
destination='MC'
source='GC'
destination_gid = 1020650

plot.plot_single_vertex_dist (env, MC_connections_path, coords_path, distances_namespace, 
                              destination_gid, destination, source, 
                              extent_type='global', bin_size=150, fontSize=font_size, saveFig=True)
